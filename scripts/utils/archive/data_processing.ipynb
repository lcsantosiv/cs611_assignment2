# %% [markdown]
# # Initialisation

# %%
import os
from pathlib import Path
import glob
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
import pprint
import pyspark
import pyspark.sql.functions as F

from pyspark.sql.functions import col, sum as spark_sum, isnan, when
from pyspark.sql.types import StringType, IntegerType, FloatType, DateType

# %%
# Initialize SparkSession
spark = pyspark.sql.SparkSession.builder \
    .appName("dev") \
    .master("local[*]") \
    .getOrCreate()

# Set log level to ERROR to hide warnings
spark.sparkContext.setLogLevel("ERROR")
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/06/21 13:48:29 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# # Set Up

# %%
bronze_dir = Path("datamart/bronze")
silver_dir = Path("datamart/silver")
gold_dir = Path("datamart/gold")

# %%
csv_files = [
    bronze_dir / "features_credit_history.csv",
    bronze_dir / "features_demographic.csv",
    bronze_dir / "features_financial.csv",
    bronze_dir / "features_loan_terms.csv"
]

# %%
for file in csv_files:
    df = spark.read.option("header", True).option("inferSchema", True).csv(str(file))
    print(f"\n=== {file.name} ===")
    df.printSchema()
    if "snapshot_date" in df.columns:
        df.select("snapshot_date").printSchema()  # see data type
        df.select("snapshot_date").show(5, truncate=False)  # preview first 5 values
    else:
        print("⚠️ 'snapshot_date' column not found.")
# Out:
# === features_credit_history.csv ===
# root
#  |-- member_id: string (nullable = true)
#  |-- snapshot_date: date (nullable = true)
#  |-- mort_acc: double (nullable = true)
#  |-- num_tl_op_past_12m: double (nullable = true)
#  |-- earliest_cr_line: string (nullable = true)
#  |-- last_credit_pull_d: string (nullable = true)
#  |-- inq_last_6mths: double (nullable = true)
#  |-- inq_last_12m: double (nullable = true)
#  |-- inq_fi: double (nullable = true)
#  |-- mths_since_last_delinq: double (nullable = true)
#  |-- mths_since_last_record: double (nullable = true)
#  |-- mths_since_last_major_derog: double (nullable = true)
#  |-- mths_since_recent_bc_dlq: double (nullable = true)
#  |-- mths_since_recent_inq: double (nullable = true)
#  |-- mths_since_recent_revol_delinq: double (nullable = true)
#  |-- mths_since_rcnt_il: double (nullable = true)
#  |-- mths_since_recent_bc: double (nullable = true)
#  |-- acc_now_delinq: double (nullable = true)
#  |-- delinq_2yrs: double (nullable = true)
#  |-- pub_rec: double (nullable = true)
#  |-- collections_12_mths_ex_med: double (nullable = true)
#  |-- chargeoff_within_12_mths: double (nullable = true)
#  |-- tax_liens: double (nullable = true)
#  |-- pub_rec_bankruptcies: double (nullable = true)
#  |-- num_tl_120dpd_2m: double (nullable = true)
#  |-- num_tl_30dpd: double (nullable = true)
#  |-- num_tl_90g_dpd_24m: double (nullable = true)
#  |-- num_accts_ever_120_pd: double (nullable = true)
#  |-- delinq_amnt: double (nullable = true)
#  |-- sec_app_chargeoff_within_12_mths: double (nullable = true)
#  |-- sec_app_collections_12_mths_ex_med: double (nullable = true)
#  |-- sec_app_mths_since_last_major_derog: double (nullable = true)
#
# root
#  |-- snapshot_date: date (nullable = true)
#
# +-------------+
# |snapshot_date|
# +-------------+
# |2022-01-01   |
# |2022-01-01   |
# |2022-01-01   |
# |2022-01-01   |
# |2022-01-01   |
# +-------------+
# only showing top 5 rows
# === features_demographic.csv ===
# root
#  |-- member_id: string (nullable = true)
#  |-- snapshot_date: date (nullable = true)
#  |-- emp_title: string (nullable = true)
#  |-- emp_length: string (nullable = true)
#  |-- home_ownership: string (nullable = true)
#  |-- annual_inc: string (nullable = true)
#  |-- verification_status: string (nullable = true)
#  |-- zip_code: string (nullable = true)
#  |-- addr_state: string (nullable = true)
#  |-- application_type: string (nullable = true)
#  |-- annual_inc_joint: string (nullable = true)
#  |-- verification_status_joint: string (nullable = true)
#  |-- sec_app_earliest_cr_line: string (nullable = true)
#  |-- sec_app_inq_last_6mths: double (nullable = true)
#  |-- sec_app_mort_acc: double (nullable = true)
#  |-- sec_app_open_acc: double (nullable = true)
#  |-- sec_app_revol_util: double (nullable = true)
#  |-- sec_app_open_act_il: double (nullable = true)
#  |-- sec_app_num_rev_accts: double (nullable = true)
#
# root
#  |-- snapshot_date: date (nullable = true)
#
# +-------------+
# |snapshot_date|
# +-------------+
# |2022-01-01   |
# |2022-01-01   |
# |2022-01-01   |
# |2022-01-01   |
# |2022-01-01   |
# +-------------+
# only showing top 5 rows
# === features_financial.csv ===
# root
#  |-- member_id: string (nullable = true)
#  |-- snapshot_date: date (nullable = true)
#  |-- dti: double (nullable = true)
#  |-- dti_joint: double (nullable = true)
#  |-- revol_bal: integer (nullable = true)
#  |-- revol_bal_joint: double (nullable = true)
#  |-- revol_util: double (nullable = true)
#  |-- total_rev_hi_lim: double (nullable = true)
#  |-- tot_coll_amt: double (nullable = true)
#  |-- tot_cur_bal: double (nullable = true)
#  |-- avg_cur_bal: double (nullable = true)
#  |-- all_util: double (nullable = true)
#  |-- max_bal_bc: double (nullable = true)
#  |-- il_util: double (nullable = true)
#  |-- bc_util: double (nullable = true)
#  |-- total_bal_il: double (nullable = true)
#  |-- total_bal_ex_mort: double (nullable = true)
#  |-- total_bc_limit: double (nullable = true)
#  |-- total_il_high_credit_limit: double (nullable = true)
#  |-- tot_hi_cred_lim: double (nullable = true)
#  |-- open_acc: double (nullable = true)
#  |-- total_acc: double (nullable = true)
#  |-- open_acc_6m: double (nullable = true)
#  |-- open_act_il: double (nullable = true)
#  |-- open_il_12m: double (nullable = true)
#  |-- open_il_24m: double (nullable = true)
#  |-- open_rv_12m: double (nullable = true)
#  |-- open_rv_24m: double (nullable = true)
#  |-- acc_open_past_24mths: double (nullable = true)
#  |-- mo_sin_old_il_acct: double (nullable = true)
#  |-- mo_sin_old_rev_tl_op: double (nullable = true)
#  |-- mo_sin_rcnt_rev_tl_op: double (nullable = true)
#  |-- mo_sin_rcnt_tl: double (nullable = true)
#  |-- num_actv_bc_tl: double (nullable = true)
#  |-- num_actv_rev_tl: double (nullable = true)
#  |-- num_rev_accts: double (nullable = true)
#  |-- num_rev_tl_bal_gt_0: double (nullable = true)
#  |-- num_il_tl: double (nullable = true)
#  |-- num_bc_tl: double (nullable = true)
#  |-- num_op_rev_tl: double (nullable = true)
#  |-- num_sats: double (nullable = true)
#  |-- num_bc_sats: double (nullable = true)
#  |-- total_cu_tl: double (nullable = true)
#  |-- bc_open_to_buy: double (nullable = true)
#  |-- percent_bc_gt_75: double (nullable = true)
#  |-- pct_tl_nvr_dlq: double (nullable = true)
#
# root
#  |-- snapshot_date: date (nullable = true)
#
# +-------------+
# |snapshot_date|
# +-------------+
# |2022-01-01   |
# |2022-01-01   |
# |2022-01-01   |
# |2022-01-01   |
# |2022-01-01   |
# +-------------+
# only showing top 5 rows
# [Stage 10:>                                                       (0 + 16) / 16]
# === features_loan_terms.csv ===
# root
#  |-- id: string (nullable = true)
#  |-- member_id: string (nullable = true)
#  |-- snapshot_date: date (nullable = true)
#  |-- loan_amnt: integer (nullable = true)
#  |-- funded_amnt: integer (nullable = true)
#  |-- funded_amnt_inv: double (nullable = true)
#  |-- term: string (nullable = true)
#  |-- int_rate: double (nullable = true)
#  |-- installment: double (nullable = true)
#  |-- grade: string (nullable = true)
#  |-- sub_grade: string (nullable = true)
#  |-- issue_d: string (nullable = true)
#  |-- loan_status: string (nullable = true)
#  |-- pymnt_plan: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- desc: string (nullable = true)
#  |-- purpose: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- initial_list_status: string (nullable = true)
#  |-- out_prncp: string (nullable = true)
#  |-- out_prncp_inv: string (nullable = true)
#  |-- total_pymnt: string (nullable = true)
#  |-- total_pymnt_inv: string (nullable = true)
#  |-- total_rec_prncp: string (nullable = true)
#  |-- total_rec_int: string (nullable = true)
#  |-- total_rec_late_fee: string (nullable = true)
#  |-- recoveries: string (nullable = true)
#  |-- collection_recovery_fee: string (nullable = true)
#  |-- last_pymnt_d: string (nullable = true)
#  |-- last_pymnt_amnt: string (nullable = true)
#  |-- next_pymnt_d: string (nullable = true)
#  |-- policy_code: string (nullable = true)
#  |-- hardship_flag: string (nullable = true)
#  |-- hardship_type: string (nullable = true)
#  |-- hardship_reason: string (nullable = true)
#  |-- hardship_status: string (nullable = true)
#  |-- deferral_term: string (nullable = true)
#  |-- hardship_amount: string (nullable = true)
#  |-- hardship_start_date: string (nullable = true)
#  |-- hardship_end_date: string (nullable = true)
#  |-- payment_plan_start_date: string (nullable = true)
#  |-- hardship_length: string (nullable = true)
#  |-- hardship_dpd: string (nullable = true)
#  |-- hardship_loan_status: string (nullable = true)
#  |-- orig_projected_additional_accrued_interest: string (nullable = true)
#  |-- hardship_payoff_balance_amount: string (nullable = true)
#  |-- hardship_last_payment_amount: string (nullable = true)
#  |-- disbursement_method: string (nullable = true)
#  |-- debt_settlement_flag: string (nullable = true)
#  |-- debt_settlement_flag_date: string (nullable = true)
#  |-- settlement_status: string (nullable = true)
#  |-- settlement_date: string (nullable = true)
#  |-- settlement_amount: string (nullable = true)
#  |-- settlement_percentage: string (nullable = true)
#  |-- settlement_term: string (nullable = true)
#
# root
#  |-- snapshot_date: date (nullable = true)
#
# +-------------+
# |snapshot_date|
# +-------------+
# |2022-01-01   |
# |2022-01-01   |
# |2022-01-01   |
# |2022-01-01   |
# |2022-01-01   |
# +-------------+
# only showing top 5 rows

# %% [markdown]
# # Config

# %%
snapshot_date_str = "2022-01-01"

start_date_str = "2022-01-01"
end_date_str = "2022-01-30"

# %%
def generate_date_list(start_date_str, end_date_str):
    start_date = datetime.strptime(start_date_str, "%Y-%m-%d").date()
    end_date = datetime.strptime(end_date_str, "%Y-%m-%d").date()

    current_date = start_date
    date_list = []

    while current_date <= end_date:
        date_list.append(current_date)
        current_date += timedelta(days=1)

    return date_list

# %%
date_list = generate_date_list(start_date_str, end_date_str)

# %%
date_list_str = [d.strftime("%Y-%m-%d") for d in date_list]

# %% [markdown]
# # Silver Level Processing

# %%
from utils.silver_processing import silver_processing

# silver_processing.py automatically splits the data by month and backfills the data accordingly
# data_window refers to the snapshot dates used
silver_processing(bronze_dir, silver_dir, data_window=date_list_str)
# Out:
# [Stage 576:=========================================>             (12 + 4) / 16]
# Silver-level processing complete.

# %% [markdown]
# ## Silver Table Schemas

# %%
folders = [
    Path("datamart/silver/demographic"), 
    Path("datamart/silver/financial"), 
    Path("datamart/silver/credit_history"),
    Path("datamart/silver/loan_terms")
]

for folder in folders:
    parquet_files = list(folder.rglob("*.parquet"))
    sample_file = random.choice(parquet_files)
    print(f"📂 Sampled file: {sample_file}")
    df = spark.read.parquet(str(sample_file))
    df.printSchema()
    df.select("member_id").show(5, truncate=False)
# Out:
# 📂 Sampled file: datamart/silver/demographic/demographic_2022-01-05/part-00000-2049cd1c-6a0a-4b0e-85a3-780ce44f683d-c000.snappy.parquet
# root
#  |-- member_id: string (nullable = true)
#  |-- snapshot_date: date (nullable = true)
#  |-- emp_title: string (nullable = true)
#  |-- emp_length: string (nullable = true)
#  |-- home_ownership: string (nullable = true)
#  |-- annual_inc: string (nullable = true)
#  |-- verification_status: string (nullable = true)
#  |-- zip_code: string (nullable = true)
#  |-- addr_state: string (nullable = true)
#  |-- application_type: string (nullable = true)
#
# +-----------+
# |member_id  |
# +-----------+
# |MEM_1000898|
# |MEM_1001193|
# |MEM_100162 |
# |MEM_1002017|
# |MEM_1002605|
# +-----------+
# only showing top 5 rows
#
# 📂 Sampled file: datamart/silver/financial/financial_2022-01-21/part-00000-ba8197c6-b9f8-4521-b14c-23dd55ddcc8f-c000.snappy.parquet
# root
#  |-- member_id: string (nullable = true)
#  |-- snapshot_date: date (nullable = true)
#  |-- dti: double (nullable = true)
#  |-- revol_bal: integer (nullable = true)
#  |-- revol_util: double (nullable = true)
#  |-- total_rev_hi_lim: double (nullable = true)
#  |-- tot_coll_amt: double (nullable = true)
#  |-- tot_cur_bal: double (nullable = true)
#  |-- avg_cur_bal: double (nullable = true)
#  |-- all_util: double (nullable = true)
#  |-- max_bal_bc: double (nullable = true)
#  |-- il_util: double (nullable = true)
#  |-- bc_util: double (nullable = true)
#  |-- total_bal_il: double (nullable = true)
#  |-- total_bal_ex_mort: double (nullable = true)
#  |-- total_bc_limit: double (nullable = true)
#  |-- total_il_high_credit_limit: double (nullable = true)
#  |-- tot_hi_cred_lim: double (nullable = true)
#  |-- open_acc: double (nullable = true)
#  |-- total_acc: double (nullable = true)
#  |-- open_acc_6m: double (nullable = true)
#  |-- open_act_il: double (nullable = true)
#  |-- open_il_12m: double (nullable = true)
#  |-- open_il_24m: double (nullable = true)
#  |-- open_rv_12m: double (nullable = true)
#  |-- open_rv_24m: double (nullable = true)
#  |-- acc_open_past_24mths: double (nullable = true)
#  |-- mo_sin_old_il_acct: double (nullable = true)
#  |-- mo_sin_old_rev_tl_op: double (nullable = true)
#  |-- mo_sin_rcnt_rev_tl_op: double (nullable = true)
#  |-- mo_sin_rcnt_tl: double (nullable = true)
#  |-- num_actv_bc_tl: double (nullable = true)
#  |-- num_actv_rev_tl: double (nullable = true)
#  |-- num_rev_accts: double (nullable = true)
#  |-- num_rev_tl_bal_gt_0: double (nullable = true)
#  |-- num_il_tl: double (nullable = true)
#  |-- num_bc_tl: double (nullable = true)
#  |-- num_op_rev_tl: double (nullable = true)
#  |-- num_sats: double (nullable = true)
#  |-- num_bc_sats: double (nullable = true)
#  |-- total_cu_tl: double (nullable = true)
#  |-- bc_open_to_buy: double (nullable = true)
#  |-- percent_bc_gt_75: double (nullable = true)
#  |-- pct_tl_nvr_dlq: double (nullable = true)
#  |-- all_util_missing: integer (nullable = true)
#  |-- il_util_missing: integer (nullable = true)
#  |-- bc_util_missing: integer (nullable = true)
#
# +-----------+
# |member_id  |
# +-----------+
# |MEM_1000158|
# |MEM_1000292|
# |MEM_1001310|
# |MEM_1001695|
# |MEM_1002062|
# +-----------+
# only showing top 5 rows
#
# 📂 Sampled file: datamart/silver/credit_history/credit_history_2022-01-30/part-00000-51c5969a-3996-4eb7-b10b-b2b99b0d046a-c000.snappy.parquet
# root
#  |-- member_id: string (nullable = true)
#  |-- snapshot_date: date (nullable = true)
#  |-- mort_acc: double (nullable = true)
#  |-- num_tl_op_past_12m: double (nullable = true)
#  |-- earliest_cr_line: date (nullable = true)
#  |-- inq_last_6mths: double (nullable = true)
#  |-- inq_last_12m: double (nullable = true)
#  |-- inq_fi: double (nullable = true)
#  |-- mths_since_last_delinq: double (nullable = true)
#  |-- mths_since_recent_inq: double (nullable = true)
#  |-- mths_since_rcnt_il: double (nullable = true)
#  |-- mths_since_recent_bc: double (nullable = true)
#  |-- acc_now_delinq: double (nullable = true)
#  |-- delinq_2yrs: double (nullable = true)
#  |-- pub_rec: double (nullable = true)
#  |-- collections_12_mths_ex_med: double (nullable = true)
#  |-- chargeoff_within_12_mths: double (nullable = true)
#  |-- tax_liens: double (nullable = true)
#  |-- pub_rec_bankruptcies: double (nullable = true)
#  |-- num_tl_120dpd_2m: double (nullable = true)
#  |-- num_tl_30dpd: double (nullable = true)
#  |-- num_tl_90g_dpd_24m: double (nullable = true)
#  |-- num_accts_ever_120_pd: double (nullable = true)
#  |-- delinq_amnt: double (nullable = true)
#  |-- mort_acc_missing: integer (nullable = true)
#  |-- months_since_earliest_cr_line: double (nullable = true)
#
# +-----------+
# |member_id  |
# +-----------+
# |MEM_1000052|
# |MEM_1000274|
# |MEM_1000735|
# |MEM_1001745|
# |MEM_1002049|
# +-----------+
# only showing top 5 rows
#
# 📂 Sampled file: datamart/silver/loan_terms/loan_terms_2022-01-28/part-00000-6dd1c4cf-459d-488f-b95b-c185d372ca80-c000.snappy.parquet
# root
#  |-- id: string (nullable = true)
#  |-- member_id: string (nullable = true)
#  |-- snapshot_date: date (nullable = true)
#  |-- loan_amnt: integer (nullable = true)
#  |-- funded_amnt: integer (nullable = true)
#  |-- funded_amnt_inv: double (nullable = true)
#  |-- term: string (nullable = true)
#  |-- int_rate: double (nullable = true)
#  |-- installment: double (nullable = true)
#  |-- grade: string (nullable = true)
#  |-- sub_grade: string (nullable = true)
#  |-- issue_d: string (nullable = true)
#  |-- loan_status: string (nullable = true)
#  |-- pymnt_plan: integer (nullable = true)
#  |-- purpose: string (nullable = true)
#  |-- initial_list_status: integer (nullable = true)
#  |-- disbursement_method: integer (nullable = true)
#  |-- debt_settlement_flag: integer (nullable = true)
#
# +-----------+
# |member_id  |
# +-----------+
# |MEM_1000646|
# |MEM_1001094|
# |MEM_1001386|
# |MEM_100144 |
# |MEM_1001884|
# +-----------+
# only showing top 5 rows

# %% [markdown]
# # Gold Level Processing

# %% [markdown]
# ## Table Processing

# %%
from utils.gold_processing import gold_processing

gold_processing(silver_dir, gold_dir, data_window=date_list_str)
# Out:
# Gold-level processing complete.

# %% [markdown]
# ### Gold Table Schemas

# %%
folders = [
    Path("datamart/gold/demographic"), 
    Path("datamart/gold/credit_history"), 
    Path("datamart/gold/financial"), 
    Path("datamart/gold/loan_terms")
]

for folder in folders:
    parquet_files = list(folder.rglob("*.parquet"))
    sample_file = random.choice(parquet_files)
    print(f"📂 Sampled file: {sample_file}")
    df = spark.read.parquet(str(sample_file))
    df.printSchema()
# Out:
# 📂 Sampled file: datamart/gold/demographic/demographic_2022-01-22/part-00000-3daccbf5-ea6c-4253-a6a9-7da5882c4001-c000.snappy.parquet
# root
#  |-- member_id: string (nullable = true)
#  |-- snapshot_date: date (nullable = true)
#  |-- annual_inc: string (nullable = true)
#  |-- home_ownership_ohe: vector (nullable = true)
#  |-- verification_status_ohe: vector (nullable = true)
#  |-- application_type_ohe: vector (nullable = true)
#
# 📂 Sampled file: datamart/gold/credit_history/credit_history_2022-02-24/part-00000-8d0dc212-7bc0-4ee5-a955-341e62360d31-c000.snappy.parquet
# root
#  |-- member_id: string (nullable = true)
#  |-- snapshot_date: date (nullable = true)
#  |-- mort_acc: double (nullable = true)
#  |-- num_tl_op_past_12m: double (nullable = true)
#  |-- inq_last_6mths: double (nullable = true)
#  |-- inq_last_12m: double (nullable = true)
#  |-- inq_fi: double (nullable = true)
#  |-- mths_since_last_delinq: double (nullable = true)
#  |-- mths_since_recent_inq: double (nullable = true)
#  |-- mths_since_rcnt_il: double (nullable = true)
#  |-- mths_since_recent_bc: double (nullable = true)
#  |-- acc_now_delinq: double (nullable = true)
#  |-- delinq_2yrs: double (nullable = true)
#  |-- pub_rec: double (nullable = true)
#  |-- collections_12_mths_ex_med: double (nullable = true)
#  |-- chargeoff_within_12_mths: double (nullable = true)
#  |-- tax_liens: double (nullable = true)
#  |-- pub_rec_bankruptcies: double (nullable = true)
#  |-- num_tl_120dpd_2m: double (nullable = true)
#  |-- num_tl_30dpd: double (nullable = true)
#  |-- num_tl_90g_dpd_24m: double (nullable = true)
#  |-- num_accts_ever_120_pd: double (nullable = true)
#  |-- delinq_amnt: double (nullable = true)
#  |-- mort_acc_missing: integer (nullable = true)
#  |-- months_since_earliest_cr_line: double (nullable = true)
#
# 📂 Sampled file: datamart/gold/financial/financial_2022-01-11/part-00000-1764166c-a996-45ac-89d2-191f6936a3db-c000.snappy.parquet
# root
#  |-- member_id: string (nullable = true)
#  |-- snapshot_date: date (nullable = true)
#  |-- dti: double (nullable = true)
#  |-- revol_bal: double (nullable = true)
#  |-- revol_util: double (nullable = true)
#  |-- total_rev_hi_lim: double (nullable = true)
#  |-- tot_coll_amt: double (nullable = true)
#  |-- tot_cur_bal: double (nullable = true)
#  |-- avg_cur_bal: double (nullable = true)
#  |-- all_util: double (nullable = true)
#  |-- max_bal_bc: double (nullable = true)
#  |-- il_util: double (nullable = true)
#  |-- bc_util: double (nullable = true)
#  |-- total_bal_il: double (nullable = true)
#  |-- total_bal_ex_mort: double (nullable = true)
#  |-- total_bc_limit: double (nullable = true)
#  |-- total_il_high_credit_limit: double (nullable = true)
#  |-- tot_hi_cred_lim: double (nullable = true)
#  |-- open_acc: double (nullable = true)
#  |-- total_acc: double (nullable = true)
#  |-- open_acc_6m: double (nullable = true)
#  |-- open_act_il: double (nullable = true)
#  |-- open_il_12m: double (nullable = true)
#  |-- open_il_24m: double (nullable = true)
#  |-- open_rv_12m: double (nullable = true)
#  |-- open_rv_24m: double (nullable = true)
#  |-- acc_open_past_24mths: double (nullable = true)
#  |-- mo_sin_old_il_acct: double (nullable = true)
#  |-- mo_sin_old_rev_tl_op: double (nullable = true)
#  |-- mo_sin_rcnt_rev_tl_op: double (nullable = true)
#  |-- mo_sin_rcnt_tl: double (nullable = true)
#  |-- num_actv_bc_tl: double (nullable = true)
#  |-- num_actv_rev_tl: double (nullable = true)
#  |-- num_rev_accts: double (nullable = true)
#  |-- num_rev_tl_bal_gt_0: double (nullable = true)
#  |-- num_il_tl: double (nullable = true)
#  |-- num_bc_tl: double (nullable = true)
#  |-- num_op_rev_tl: double (nullable = true)
#  |-- num_sats: double (nullable = true)
#  |-- num_bc_sats: double (nullable = true)
#  |-- total_cu_tl: double (nullable = true)
#  |-- bc_open_to_buy: double (nullable = true)
#  |-- percent_bc_gt_75: double (nullable = true)
#  |-- pct_tl_nvr_dlq: double (nullable = true)
#  |-- all_util_missing: double (nullable = true)
#  |-- il_util_missing: double (nullable = true)
#  |-- bc_util_missing: double (nullable = true)
#
# 📂 Sampled file: datamart/gold/loan_terms/loan_terms_2022-01-25/part-00000-c0e9954c-3550-404c-ade4-f5225e588a35-c000.snappy.parquet
# root
#  |-- id: string (nullable = true)
#  |-- member_id: string (nullable = true)
#  |-- snapshot_date: date (nullable = true)
#  |-- loan_amnt: integer (nullable = true)
#  |-- funded_amnt: integer (nullable = true)
#  |-- funded_amnt_inv: double (nullable = true)
#  |-- term: integer (nullable = true)
#  |-- int_rate: double (nullable = true)
#  |-- installment: double (nullable = true)
#  |-- grade: integer (nullable = true)
#  |-- pymnt_plan: integer (nullable = true)
#  |-- initial_list_status: integer (nullable = true)
#  |-- disbursement_method: integer (nullable = true)
#  |-- debt_settlement_flag: integer (nullable = true)
#  |-- purpose_ohe: vector (nullable = true)
#  |-- loan_status_ohe: vector (nullable = true)

# %% [markdown]
# ## Label Store

# %%
from utils.gold_label_store import create_gold_label_store

create_gold_label_store(silver_dir, gold_dir, data_window=date_list_str)
# Out:
# Gold label store written to: datamart/gold/label_store

# %%
label_df = spark.read.parquet("datamart/gold/label_store")
label_df.printSchema()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- snapshot_date: date (nullable = true)
#  |-- grade: string (nullable = true)

# %% [markdown]
# ## Feature Store

# %%
from utils.gold_feature_store import create_feature_store

df = create_feature_store(silver_dir, gold_dir, data_window=date_list)
# Out:
# ['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'int_rate', 'installment', 'term_0', 'term_1', 'term_2', 'loan_status_0', 'loan_status_1', 'loan_status_2', 'loan_status_3', 'loan_status_4', 'loan_status_5', 'loan_status_6', 'loan_status_7', 'loan_status_8', 'pymnt_plan_0', 'pymnt_plan_1', 'pymnt_plan_2', 'purpose_0', 'purpose_1', 'purpose_2', 'purpose_3', 'purpose_4', 'purpose_5', 'purpose_6', 'purpose_7', 'purpose_8', 'purpose_9', 'purpose_10', 'purpose_11', 'purpose_12', 'purpose_13', 'purpose_14', 'purpose_15', 'purpose_16', 'purpose_17', 'purpose_18', 'purpose_19', 'purpose_20', 'purpose_21', 'purpose_22', 'purpose_23', 'purpose_24', 'purpose_25', 'purpose_26', 'purpose_27', 'initial_list_status_0', 'initial_list_status_1', 'initial_list_status_2', 'disbursement_method_0', 'disbursement_method_1', 'disbursement_method_2', 'debt_settlement_flag_0', 'debt_settlement_flag_1', 'debt_settlement_flag_2', 'emp_length', 'annual_inc', 'emp_title_ohe_0', 'emp_title_ohe_1', 'emp_title_ohe_2', 'emp_title_ohe_3', 'emp_title_ohe_4', 'emp_title_ohe_5', 'emp_title_ohe_6', 'emp_title_ohe_7', 'emp_title_ohe_8', 'emp_title_ohe_9', 'emp_title_ohe_10', 'home_ownership_index', 'verification_status_index', 'addr_state_index', 'application_type_index', 'home_ownership_ohe_0', 'home_ownership_ohe_1', 'home_ownership_ohe_2', 'home_ownership_ohe_3', 'home_ownership_ohe_4', 'home_ownership_ohe_5', 'verification_status_ohe_0', 'verification_status_ohe_1', 'verification_status_ohe_2', 'addr_state_ohe_0', 'addr_state_ohe_1', 'addr_state_ohe_2', 'addr_state_ohe_3', 'addr_state_ohe_4', 'addr_state_ohe_5', 'addr_state_ohe_6', 'addr_state_ohe_7', 'addr_state_ohe_8', 'addr_state_ohe_9', 'addr_state_ohe_10', 'addr_state_ohe_11', 'addr_state_ohe_12', 'addr_state_ohe_13', 'addr_state_ohe_14', 'addr_state_ohe_15', 'addr_state_ohe_16', 'addr_state_ohe_17', 'addr_state_ohe_18', 'addr_state_ohe_19', 'addr_state_ohe_20', 'addr_state_ohe_21', 'addr_state_ohe_22', 'addr_state_ohe_23', 'addr_state_ohe_24', 'addr_state_ohe_25', 'addr_state_ohe_26', 'addr_state_ohe_27', 'addr_state_ohe_28', 'addr_state_ohe_29', 'addr_state_ohe_30', 'addr_state_ohe_31', 'addr_state_ohe_32', 'addr_state_ohe_33', 'addr_state_ohe_34', 'addr_state_ohe_35', 'addr_state_ohe_36', 'addr_state_ohe_37', 'addr_state_ohe_38', 'addr_state_ohe_39', 'addr_state_ohe_40', 'addr_state_ohe_41', 'addr_state_ohe_42', 'addr_state_ohe_43', 'addr_state_ohe_44', 'addr_state_ohe_45', 'addr_state_ohe_46', 'addr_state_ohe_47', 'addr_state_ohe_48', 'addr_state_ohe_49', 'application_type_ohe_0', 'application_type_ohe_1', 'dti', 'revol_bal', 'revol_util', 'total_rev_hi_lim', 'tot_coll_amt', 'tot_cur_bal', 'avg_cur_bal', 'all_util', 'max_bal_bc', 'il_util', 'bc_util', 'total_bal_il', 'total_bal_ex_mort', 'total_bc_limit', 'total_il_high_credit_limit', 'tot_hi_cred_lim', 'open_acc', 'total_acc', 'open_acc_6m', 'open_act_il', 'open_il_12m', 'open_il_24m', 'open_rv_12m', 'open_rv_24m', 'acc_open_past_24mths', 'mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl', 'num_actv_bc_tl', 'num_actv_rev_tl', 'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_il_tl', 'num_bc_tl', 'num_op_rev_tl', 'num_sats', 'num_bc_sats', 'total_cu_tl', 'bc_open_to_buy', 'percent_bc_gt_75', 'pct_tl_nvr_dlq', 'all_util_missing', 'il_util_missing', 'bc_util_missing', 'mort_acc', 'num_tl_op_past_12m', 'inq_last_6mths', 'inq_last_12m', 'inq_fi', 'mths_since_last_delinq', 'mths_since_recent_inq', 'mths_since_rcnt_il', 'mths_since_recent_bc', 'acc_now_delinq', 'delinq_2yrs', 'pub_rec', 'collections_12_mths_ex_med', 'chargeoff_within_12_mths', 'tax_liens', 'pub_rec_bankruptcies', 'num_tl_120dpd_2m', 'num_tl_30dpd', 'num_tl_90g_dpd_24m', 'num_accts_ever_120_pd', 'delinq_amnt', 'mort_acc_missing', 'months_since_earliest_cr_line', 'earliest_cr_date', 'snapshot_month', 'earliest_cr_month', 'months_since_earliest_cr']
# Gold label store written to: datamart/gold/feature_store

# %%
features_df = spark.read.parquet("datamart/gold/feature_store")
features_df.printSchema()
# Out:
# root
#  |-- loan_amnt: float (nullable = true)
#  |-- funded_amnt: float (nullable = true)
#  |-- funded_amnt_inv: float (nullable = true)
#  |-- int_rate: float (nullable = true)
#  |-- installment: float (nullable = true)
#  |-- term_0: double (nullable = true)
#  |-- term_1: double (nullable = true)
#  |-- term_2: double (nullable = true)
#  |-- loan_status_0: double (nullable = true)
#  |-- loan_status_1: double (nullable = true)
#  |-- loan_status_2: double (nullable = true)
#  |-- loan_status_3: double (nullable = true)
#  |-- loan_status_4: double (nullable = true)
#  |-- loan_status_5: double (nullable = true)
#  |-- loan_status_6: double (nullable = true)
#  |-- loan_status_7: double (nullable = true)
#  |-- loan_status_8: double (nullable = true)
#  |-- pymnt_plan_0: double (nullable = true)
#  |-- pymnt_plan_1: double (nullable = true)
#  |-- pymnt_plan_2: double (nullable = true)
#  |-- purpose_0: double (nullable = true)
#  |-- purpose_1: double (nullable = true)
#  |-- purpose_2: double (nullable = true)
#  |-- purpose_3: double (nullable = true)
#  |-- purpose_4: double (nullable = true)
#  |-- purpose_5: double (nullable = true)
#  |-- purpose_6: double (nullable = true)
#  |-- purpose_7: double (nullable = true)
#  |-- purpose_8: double (nullable = true)
#  |-- purpose_9: double (nullable = true)
#  |-- purpose_10: double (nullable = true)
#  |-- purpose_11: double (nullable = true)
#  |-- purpose_12: double (nullable = true)
#  |-- purpose_13: double (nullable = true)
#  |-- purpose_14: double (nullable = true)
#  |-- purpose_15: double (nullable = true)
#  |-- purpose_16: double (nullable = true)
#  |-- purpose_17: double (nullable = true)
#  |-- purpose_18: double (nullable = true)
#  |-- purpose_19: double (nullable = true)
#  |-- purpose_20: double (nullable = true)
#  |-- purpose_21: double (nullable = true)
#  |-- purpose_22: double (nullable = true)
#  |-- purpose_23: double (nullable = true)
#  |-- purpose_24: double (nullable = true)
#  |-- purpose_25: double (nullable = true)
#  |-- purpose_26: double (nullable = true)
#  |-- purpose_27: double (nullable = true)
#  |-- initial_list_status_0: double (nullable = true)
#  |-- initial_list_status_1: double (nullable = true)
#  |-- initial_list_status_2: double (nullable = true)
#  |-- disbursement_method_0: double (nullable = true)
#  |-- disbursement_method_1: double (nullable = true)
#  |-- disbursement_method_2: double (nullable = true)
#  |-- debt_settlement_flag_0: double (nullable = true)
#  |-- debt_settlement_flag_1: double (nullable = true)
#  |-- debt_settlement_flag_2: double (nullable = true)
#  |-- emp_length: integer (nullable = true)
#  |-- annual_inc: float (nullable = true)
#  |-- emp_title_ohe_0: double (nullable = true)
#  |-- emp_title_ohe_1: double (nullable = true)
#  |-- emp_title_ohe_2: double (nullable = true)
#  |-- emp_title_ohe_3: double (nullable = true)
#  |-- emp_title_ohe_4: double (nullable = true)
#  |-- emp_title_ohe_5: double (nullable = true)
#  |-- emp_title_ohe_6: double (nullable = true)
#  |-- emp_title_ohe_7: double (nullable = true)
#  |-- emp_title_ohe_8: double (nullable = true)
#  |-- emp_title_ohe_9: double (nullable = true)
#  |-- emp_title_ohe_10: double (nullable = true)
#  |-- home_ownership_index: double (nullable = true)
#  |-- verification_status_index: double (nullable = true)
#  |-- addr_state_index: double (nullable = true)
#  |-- application_type_index: double (nullable = true)
#  |-- home_ownership_ohe_0: double (nullable = true)
#  |-- home_ownership_ohe_1: double (nullable = true)
#  |-- home_ownership_ohe_2: double (nullable = true)
#  |-- home_ownership_ohe_3: double (nullable = true)
#  |-- home_ownership_ohe_4: double (nullable = true)
#  |-- home_ownership_ohe_5: double (nullable = true)
#  |-- verification_status_ohe_0: double (nullable = true)
#  |-- verification_status_ohe_1: double (nullable = true)
#  |-- verification_status_ohe_2: double (nullable = true)
#  |-- addr_state_ohe_0: double (nullable = true)
#  |-- addr_state_ohe_1: double (nullable = true)
#  |-- addr_state_ohe_2: double (nullable = true)
#  |-- addr_state_ohe_3: double (nullable = true)
#  |-- addr_state_ohe_4: double (nullable = true)
#  |-- addr_state_ohe_5: double (nullable = true)
#  |-- addr_state_ohe_6: double (nullable = true)
#  |-- addr_state_ohe_7: double (nullable = true)
#  |-- addr_state_ohe_8: double (nullable = true)
#  |-- addr_state_ohe_9: double (nullable = true)
#  |-- addr_state_ohe_10: double (nullable = true)
#  |-- addr_state_ohe_11: double (nullable = true)
#  |-- addr_state_ohe_12: double (nullable = true)
#  |-- addr_state_ohe_13: double (nullable = true)
#  |-- addr_state_ohe_14: double (nullable = true)
#  |-- addr_state_ohe_15: double (nullable = true)
#  |-- addr_state_ohe_16: double (nullable = true)
#  |-- addr_state_ohe_17: double (nullable = true)
#  |-- addr_state_ohe_18: double (nullable = true)
#  |-- addr_state_ohe_19: double (nullable = true)
#  |-- addr_state_ohe_20: double (nullable = true)
#  |-- addr_state_ohe_21: double (nullable = true)
#  |-- addr_state_ohe_22: double (nullable = true)
#  |-- addr_state_ohe_23: double (nullable = true)
#  |-- addr_state_ohe_24: double (nullable = true)
#  |-- addr_state_ohe_25: double (nullable = true)
#  |-- addr_state_ohe_26: double (nullable = true)
#  |-- addr_state_ohe_27: double (nullable = true)
#  |-- addr_state_ohe_28: double (nullable = true)
#  |-- addr_state_ohe_29: double (nullable = true)
#  |-- addr_state_ohe_30: double (nullable = true)
#  |-- addr_state_ohe_31: double (nullable = true)
#  |-- addr_state_ohe_32: double (nullable = true)
#  |-- addr_state_ohe_33: double (nullable = true)
#  |-- addr_state_ohe_34: double (nullable = true)
#  |-- addr_state_ohe_35: double (nullable = true)
#  |-- addr_state_ohe_36: double (nullable = true)
#  |-- addr_state_ohe_37: double (nullable = true)
#  |-- addr_state_ohe_38: double (nullable = true)
#  |-- addr_state_ohe_39: double (nullable = true)
#  |-- addr_state_ohe_40: double (nullable = true)
#  |-- addr_state_ohe_41: double (nullable = true)
#  |-- addr_state_ohe_42: double (nullable = true)
#  |-- addr_state_ohe_43: double (nullable = true)
#  |-- addr_state_ohe_44: double (nullable = true)
#  |-- addr_state_ohe_45: double (nullable = true)
#  |-- addr_state_ohe_46: double (nullable = true)
#  |-- addr_state_ohe_47: double (nullable = true)
#  |-- addr_state_ohe_48: double (nullable = true)
#  |-- addr_state_ohe_49: double (nullable = true)
#  |-- application_type_ohe_0: double (nullable = true)
#  |-- application_type_ohe_1: double (nullable = true)
#  |-- dti: float (nullable = true)
#  |-- revol_bal: float (nullable = true)
#  |-- revol_util: float (nullable = true)
#  |-- total_rev_hi_lim: float (nullable = true)
#  |-- tot_coll_amt: float (nullable = true)
#  |-- tot_cur_bal: float (nullable = true)
#  |-- avg_cur_bal: float (nullable = true)
#  |-- all_util: float (nullable = true)
#  |-- max_bal_bc: float (nullable = true)
#  |-- il_util: float (nullable = true)
#  |-- bc_util: float (nullable = true)
#  |-- total_bal_il: float (nullable = true)
#  |-- total_bal_ex_mort: float (nullable = true)
#  |-- total_bc_limit: float (nullable = true)
#  |-- total_il_high_credit_limit: float (nullable = true)
#  |-- tot_hi_cred_lim: float (nullable = true)
#  |-- open_acc: integer (nullable = true)
#  |-- total_acc: integer (nullable = true)
#  |-- open_acc_6m: integer (nullable = true)
#  |-- open_act_il: integer (nullable = true)
#  |-- open_il_12m: integer (nullable = true)
#  |-- open_il_24m: integer (nullable = true)
#  |-- open_rv_12m: integer (nullable = true)
#  |-- open_rv_24m: integer (nullable = true)
#  |-- acc_open_past_24mths: integer (nullable = true)
#  |-- mo_sin_old_il_acct: integer (nullable = true)
#  |-- mo_sin_old_rev_tl_op: integer (nullable = true)
#  |-- mo_sin_rcnt_rev_tl_op: integer (nullable = true)
#  |-- mo_sin_rcnt_tl: integer (nullable = true)
#  |-- num_actv_bc_tl: integer (nullable = true)
#  |-- num_actv_rev_tl: integer (nullable = true)
#  |-- num_rev_accts: integer (nullable = true)
#  |-- num_rev_tl_bal_gt_0: integer (nullable = true)
#  |-- num_il_tl: integer (nullable = true)
#  |-- num_bc_tl: integer (nullable = true)
#  |-- num_op_rev_tl: integer (nullable = true)
#  |-- num_sats: integer (nullable = true)
#  |-- num_bc_sats: integer (nullable = true)
#  |-- total_cu_tl: integer (nullable = true)
#  |-- bc_open_to_buy: float (nullable = true)
#  |-- percent_bc_gt_75: float (nullable = true)
#  |-- pct_tl_nvr_dlq: float (nullable = true)
#  |-- all_util_missing: integer (nullable = true)
#  |-- il_util_missing: integer (nullable = true)
#  |-- bc_util_missing: integer (nullable = true)
#  |-- mort_acc: integer (nullable = true)
#  |-- num_tl_op_past_12m: integer (nullable = true)
#  |-- inq_last_6mths: integer (nullable = true)
#  |-- inq_last_12m: integer (nullable = true)
#  |-- inq_fi: integer (nullable = true)
#  |-- mths_since_last_delinq: integer (nullable = true)
#  |-- mths_since_recent_inq: integer (nullable = true)
#  |-- mths_since_rcnt_il: integer (nullable = true)
#  |-- mths_since_recent_bc: integer (nullable = true)
#  |-- acc_now_delinq: integer (nullable = true)
#  |-- delinq_2yrs: integer (nullable = true)
#  |-- pub_rec: integer (nullable = true)
#  |-- collections_12_mths_ex_med: integer (nullable = true)
#  |-- chargeoff_within_12_mths: integer (nullable = true)
#  |-- tax_liens: integer (nullable = true)
#  |-- pub_rec_bankruptcies: integer (nullable = true)
#  |-- num_tl_120dpd_2m: integer (nullable = true)
#  |-- num_tl_30dpd: integer (nullable = true)
#  |-- num_tl_90g_dpd_24m: integer (nullable = true)
#  |-- num_accts_ever_120_pd: integer (nullable = true)
#  |-- delinq_amnt: integer (nullable = true)
#  |-- mort_acc_missing: integer (nullable = true)
#  |-- months_since_earliest_cr_line: double (nullable = true)
#  |-- earliest_cr_date: date (nullable = true)
#  |-- snapshot_month: date (nullable = true)
#  |-- earliest_cr_month: date (nullable = true)
#  |-- months_since_earliest_cr: integer (nullable = true)
